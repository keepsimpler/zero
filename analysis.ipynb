# %% [markdown]
# ## Result Data Explore

# %%
import pandas as pd
# %matplotlib notebook

# %%
res = pd.read_csv('runs/LinkContainer/stats.csv')
#res = pd.read_csv('runs/LinearContainer/stats.csv')

# %%
#res.to_csv('runs/base_model/stats.csv',index=False)

# %%
res.index.name

# %%
res2 = res[['evaluate_accuracy_avg', 'train_accuracy_avg']]
max(res2['evaluate_accuracy_avg'])
# Out:
# 0.9018710191082804

# %%
res2.plot()
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
res3 = res[['evaluate_loss_avg', 'train_loss_avg']]

# %%
res3.plot()
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
res.columns
# Out:
# Index(['train_batch_size', 'test_batch_size', 'num_workers', 'learning_rate',
#        'num_epochs', 'save_summary_steps', 'wide_of_layers', 'act_fn_name',
#        'model', 'optimizer', 'cuda', 'train_accuracy_avg', 'train_loss_avg',
#        'evaluate_accuracy_avg', 'evaluate_loss_avg', 'layers.0.weight.norm',
#        'layers.0.weight.grad.norm', 'layers.0.bias.norm',
#        'layers.0.bias.grad.norm', 'layers.1.weight.norm',
#        'layers.1.weight.grad.norm', 'layers.1.bias.norm',
#        'layers.1.bias.grad.norm', 'epoch'],
#       dtype='object')

# %%
res4 = res[['layers.1.weight.grad.norm']]
res4.plot()
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
res5 = res[['layers.0.weight.grad.norm']]
res5.plot()
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
res_bias = res[['layers.1.bias.grad.norm']]
res_bias.plot()
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
res_bias = res[['layers.0.bias.grad.norm']]
res_bias.plot()
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %% [markdown]
# ## Result Data Explore

# %%
import pandas as pd
# %matplotlib notebook

# %%
res = pd.read_csv('runs/base_model/stats.csv')

# %%
#res.to_csv('runs/base_model/stats.csv',index=False)

# %%
res.index.name

# %%
res2 = res[['evaluate_accuracy_avg', 'train_accuracy_avg']]

# %%
res2.plot()
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
res3 = res[['evaluate_loss_avg', 'train_loss_avg']]

# %%
res3.plot()
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
res.columns
# Out:
# Index(['train_batch_size', 'test_batch_size', 'num_workers', 'learning_rate',
#        'num_epochs', 'save_summary_steps', 'wide_of_layers', 'act_fn_name',
#        'cuda', 'train_accuracy_avg', 'train_loss_avg', 'evaluate_accuracy_avg',
#        'evaluate_loss_avg', 'layers.0.weight.mean',
#        'layers.0.weight.grad.mean', 'layers.0.bias.mean',
#        'layers.0.bias.grad.mean', 'layers.1.weight.mean',
#        'layers.1.weight.grad.mean', 'layers.1.bias.mean',
#        'layers.1.bias.grad.mean', 'epoch'],
#       dtype='object')

# %%
res4 = res[['layers.0.weight.mean']]
res4.plot()
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
res_bias = res[['layers.0.weight.grad.mean']]
res_bias.plot()
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
res_bias = res[['layers.1.weight.mean']]
res_bias.plot()
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
res_bias = res[['layers.1.weight.grad.mean']]
res_bias.plot()
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">
